# %% [markdown]
# ## Neural Network Regression with TensorFlow
#
# ![hyperparameters.png](data:image/png;base64,...)

# %% [markdown]
# ### prediction numerical variable based on some combination of variables

# %%
# import tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
# creating data
import numpy as np
import matplotlib.pyplot as plt

# create features
X = np.array([-8.0, -5.0, -2.0, 1.0, 4.0, 7.0, 10.0, 13.0])

# create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

#visualize
plt.scatter(X, y)

# %%
y == X + 11
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### input and output shapes

# %%
# create demo tensor for housing price prediction
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X.shape
output_shape = y.shape
input_shape, output_shape
# Out:
# ((8,), (8,))

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape 
#they are scalar and not shape
# Out:
# ((), ())

# %%
X[0].ndim
# Out:
# 0

# %%
X[0], y[0]
# Out:
# (-8.0, 3.0)

# %%
# turn numpy arrays to tensors
X = tf.cast(tf.constant(X),dtype=tf.float32)
y = tf.cast(tf.constant(y),dtype=tf.float32)
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
X[0], y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=-8.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=3.0>)

# %% [markdown]
# ### steps in modelling with tensorflow
#
#
# 1.   **creating model** : define input and output layers as well as hidden layers
# 2.   **compiling model** : define loss function ( how much model is wrong), optimizer ( how to improve) and evaluation metrics ( what we can use to interpret the performance of the model)
# 3.   **fitting a model** : letting the model to try to find patterns between X and y (features and labels)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([tf.keras.layers.Dense(1)])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), # SGD is short for stochastic gradient descent
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 540ms/step - loss: 12.0749 - mae: 12.0749
# Epoch 2/5
# 1/1 [==============================] - 0s 7ms/step - loss: 12.0023 - mae: 12.0023
# Epoch 3/5
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9299 - mae: 11.9299
# Epoch 4/5
# 1/1 [==============================] - 0s 9ms/step - loss: 11.8574 - mae: 11.8574
# Epoch 5/5
# 1/1 [==============================] - 0s 4ms/step - loss: 11.7849 - mae: 11.7849

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model
model.predict([17.0])
# Out:
# array([[11.866016]], dtype=float32)

# %% [markdown]
# ### improve the model
#
# 1.   adding layers
# 2.   increase number of hidden units
# 3.   change activation functions
# 4.   change opti;ization function
# 5.   change learning rate
# 6.   fitting on more date
# 7.   fitting longer

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 274ms/step - loss: 12.0749 - mae: 12.0749
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 12.0023 - mae: 12.0023
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 11.9299 - mae: 11.9299
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.8574 - mae: 11.8574
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.7849 - mae: 11.7849
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.7124 - mae: 11.7124
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.6399 - mae: 11.6399
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.5674 - mae: 11.5674
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.4949 - mae: 11.4949
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.4223 - mae: 11.4223
# Epoch 11/100
# ...

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[29.220901]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(100, activation="relu"),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 368ms/step - loss: 12.4199 - mae: 12.4199
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 11.9628 - mae: 11.9628
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.5002 - mae: 11.5002
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.0281 - mae: 11.0281
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.5473 - mae: 10.5473
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.0488 - mae: 10.0488
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5275 - mae: 9.5275
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.9792 - mae: 8.9792
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4162 - mae: 8.4162
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.8876 - mae: 7.8876
# Epoch 11/100
# ...

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[32.468384]], dtype=float32)

# %% [markdown]
# --> overfitting

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(50),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 313ms/step - loss: 13.2729 - mae: 13.2729
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.0132 - mae: 13.0132
# Epoch 3/100
# 1/1 [==============================] - 0s 12ms/step - loss: 12.7525 - mae: 12.7525
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.4901 - mae: 12.4901
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 12.2252 - mae: 12.2252
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9570 - mae: 11.9570
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.6850 - mae: 11.6850
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.4082 - mae: 11.4082
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.1259 - mae: 11.1259
# Epoch 10/100
# 1/1 [==============================] - 0s 15ms/step - loss: 10.8374 - mae: 10.8374
# Epoch 11/100
# ...

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[29.296755]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(50),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 359ms/step - loss: 13.2729 - mae: 13.2729
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.7634 - mae: 12.7634
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.2506 - mae: 12.2506
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.7329 - mae: 11.7329
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.2082 - mae: 11.2082
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6741 - mae: 10.6741
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.1280 - mae: 10.1280
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.5675 - mae: 9.5675
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.9901 - mae: 8.9901
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3938 - mae: 8.3938
# Epoch 11/100
# ...

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fda14c697a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[27.288563]], dtype=float32)

# %% [markdown]
# --> not perfect but better
#
# --> changing learning rate often efficient as well as fitting with more data

# %% [markdown]
# ### evaluating model
#
# In practice, typical workflow =
# Build a model --> fit it --> evaluate it --> tweak it  --> fit it --> evaluate it --> tweak it ....
# When it comes to evaluation, there are 3 words to remember: "visualize, visualize, visualize."
#
# It's a good idea to visualize:
#
# *   The data - what data are you working with? What does it look like?
# *   The model itself - what does the architecture look like? What are the different shapes?
# *   The training of a model - how does a model perform while it learns?
# *   The predictions of a model - how do the predictions of a model line up against the ground truth (the original labels)?

# %%
# Make a bigger dataset
X = np.arange(-100, 100, 4)
X
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
# Make labels for the dataset (adhering to the same pattern as before)
y = np.arange(-90, 110, 4)
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Same result as above
y = X + 10
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# ### The 3 sets
# One of the other most common and important steps in a machine learning project is creating a training and test set (and when required, a validation set).
#
# Here are the 3 sets:
#
# * **Training set** - the model learns from this data, which is typically 70-80% of the total data available (like the course materials you study during the semester).
# * **Validation set** - the model gets tuned on this data, which is typically 10-15% of the total data available (like the practice exam you take before the final exam).
# * **Test set** - the model gets evaluated on this data to test what it has learned, it's typically 10-15% of the total data available (like the final exam you take at the end of the semester).

# %%
# Split data into train and test sets
X_train = X[:40] # first 40 examples (80% of data)
y_train = y[:40]

X_test = X[40:] # last 10 examples (20% of data)
y_test = y[40:]

len(X_train), len(X_test)
# Out:
# (40, 10)

# %% [markdown]
# ### Visualizing the data
#
# Now we've got our training and test data, let's visualize it.

# %%
plt.figure(figsize=(8, 6))
# Plot training data in blue
plt.scatter(X_train, y_train, c="b", label="Training data")
# Plot test data in green
plt.scatter(X_test, y_test, c="g", label="Testing data")
# Show the legend
plt.legend();

# %% [markdown]
# If we don't build / fit the model, we need to add input_shape before calling summary

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, input_shape=[1], name="input_layer"), # define the input_shape to our model
  tf.keras.layers.Dense(1, input_shape=[1], name="output_layer")
], name="one_of_the_models")

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit model (same as above)
#model.fit(X_train, y_train, epochs=100) # commented out on purpose (not fitting it just yet)

# %% [markdown]
# **Visualizing the model**
#
# After you've built a model, you might want to take a look at it.
# You can take a look at the layers and shapes of your model by calling summary() on it.

# %%
# This will work after specifying the input shape
model.summary()
# Out:
# Model: "one_of_the_models"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 10)                20
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Calling summary() on our model shows us the layers it contains, the output shape and the number of parameters.
#
# * Total params - total number of parameters in the model.
# * Trainable parameters - these are the parameters (patterns) the model can update as it trains.
# * Non-trainable parameters - these parameters aren't updated during training (this is typical when you bring in the already learned patterns from other models during transfer learning).

# %%
# Fit model (same as above)
model.fit(X_train, y_train, epochs=100, verbose=0) # we can add verbose=0 if we don't want the output

# %%
# Check the model summary
model.summary()
# Out:
# Model: "one_of_the_models"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 10)                20
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# To view 2D plot of the model use plot_model()

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)

# %% [markdown]
# can be very helpful for debugging

# %% [markdown]
# ### Visualizing our model's predictions
# To visualize predictions, it's a good idea to plot them against the ground truth labels.
# Often you'll see this in the form of y_test or y_true versus y_pred (ground truth versus predictions).

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[ 70.55218 ],
#        [ 75.13991 ],
#        [ 79.72763 ],
#        [ 84.31535 ],
#        [ 88.903076],
#        [ 93.49081 ],
#        [ 98.07853 ],
#        [102.66625 ],
#        [107.253975],
#        [111.8417  ]], dtype=float32)

# %%
y_test
# Out:
# array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %% [markdown]
# Let's create a plotting function

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=y_pred):
  """
  Plots training data, test data and compares predictions to ground truth labels
  """
  plt.figure(figsize=(12,8))
  #plot training data in blue
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  #plot test data in green
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  # plot the model's predictions in red
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  # show the legend
  plt.legend()

# %%
plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=y_pred)

# %% [markdown]
# ### Evaluating our model's predictions with regression evaluation metrics
