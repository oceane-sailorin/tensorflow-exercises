# %% [markdown]
# ## Neural Network Regression with TensorFlow
#
# ![hyperparameters.png](data:image/png;base64,...)

# %% [markdown]
# ### prediction numerical variable based on some combination of variables

# %%
# import tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
# creating data
import numpy as np
import matplotlib.pyplot as plt

# create features
X = np.array([-8.0, -5.0, -2.0, 1.0, 4.0, 7.0, 10.0, 13.0])

# create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

#visualize
plt.scatter(X, y)

# %%
y == X + 11
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### input and output shapes

# %%
# create demo tensor for housing price prediction
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X.shape
output_shape = y.shape
input_shape, output_shape
# Out:
# ((8,), (8,))

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape 
#they are scalar and not shape
# Out:
# ((), ())

# %%
X[0].ndim
# Out:
# 0

# %%
X[0], y[0]
# Out:
# (-8.0, 3.0)

# %%
# turn numpy arrays to tensors
X = tf.cast(tf.constant(X),dtype=tf.float32)
y = tf.cast(tf.constant(y),dtype=tf.float32)
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
X[0], y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=-8.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=3.0>)

# %% [markdown]
# ### steps in modelling with tensorflow
#
#
# 1.   **creating model** : define input and output layers as well as hidden layers
# 2.   **compiling model** : define loss function ( how much model is wrong), optimizer ( how to improve) and evaluation metrics ( what we can use to interpret the performance of the model)
# 3.   **fitting a model** : letting the model to try to find patterns between X and y (features and labels)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([tf.keras.layers.Dense(1)])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), # SGD is short for stochastic gradient descent
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 572ms/step - loss: 12.0749 - mae: 12.0749
# Epoch 2/5
# 1/1 [==============================] - 0s 3ms/step - loss: 12.0023 - mae: 12.0023
# Epoch 3/5
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9299 - mae: 11.9299
# Epoch 4/5
# 1/1 [==============================] - 0s 6ms/step - loss: 11.8574 - mae: 11.8574
# Epoch 5/5
# 1/1 [==============================] - 0s 6ms/step - loss: 11.7849 - mae: 11.7849

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model
model.predict([17.0])
# Out:
# array([[11.866016]], dtype=float32)

# %% [markdown]
# ### improve the model
#
# 1.   adding layers
# 2.   increase number of hidden units
# 3.   change activation functions
# 4.   change opti;ization function
# 5.   change learning rate
# 6.   fitting on more date
# 7.   fitting longer

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 267ms/step - loss: 12.0749 - mae: 12.0749
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.0023 - mae: 12.0023
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9299 - mae: 11.9299
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.8574 - mae: 11.8574
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.7849 - mae: 11.7849
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.7124 - mae: 11.7124
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.6399 - mae: 11.6399
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.5674 - mae: 11.5674
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.4949 - mae: 11.4949
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.4223 - mae: 11.4223
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.3499 - mae: 11.3499
# Epoch 12/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.2774 - mae: 11.2774
# Epoch 13/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.2049 - mae: 11.2049
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.1324 - mae: 11.1324
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.0599 - mae: 11.0599
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.9874 - mae: 10.9874
# Epoch 17/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.9149 - mae: 10.9149
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.8424 - mae: 10.8424
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.7699 - mae: 10.7699
# Epoch 20/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6974 - mae: 10.6974
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6249 - mae: 10.6249
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.5524 - mae: 10.5524
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.4799 - mae: 10.4799
# Epoch 24/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.4074 - mae: 10.4074
# Epoch 25/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.3349 - mae: 10.3349
# Epoch 26/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.2624 - mae: 10.2624
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.1899 - mae: 10.1899
# Epoch 28/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.1174 - mae: 10.1174
# Epoch 29/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.0449 - mae: 10.0449
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 9.9724 - mae: 9.9724
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.8999 - mae: 9.8999
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8274 - mae: 9.8274
# Epoch 33/100
# 1/1 [==============================] - 0s 4ms/step - loss: 9.7549 - mae: 9.7549
# Epoch 34/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.6824 - mae: 9.6824
# Epoch 35/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.6099 - mae: 9.6099
# Epoch 36/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.5374 - mae: 9.5374
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.4649 - mae: 9.4649
# Epoch 38/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3924 - mae: 9.3924
# Epoch 39/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.3199 - mae: 9.3199
# Epoch 40/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2474 - mae: 9.2474
# Epoch 41/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.1749 - mae: 9.1749
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.1024 - mae: 9.1024
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0299 - mae: 9.0299
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9574 - mae: 8.9574
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8849 - mae: 8.8849
# Epoch 46/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.8124 - mae: 8.8124
# Epoch 47/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.7399 - mae: 8.7399
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6674 - mae: 8.6674
# Epoch 49/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.5949 - mae: 8.5949
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.5224 - mae: 8.5224
# Epoch 51/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4900 - mae: 8.4900
# Epoch 52/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4788 - mae: 8.4788
# Epoch 53/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4724 - mae: 8.4724
# Epoch 54/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4788 - mae: 8.4788
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4675 - mae: 8.4675
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4563 - mae: 8.4563
# Epoch 57/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4450 - mae: 8.4450
# Epoch 58/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4449 - mae: 8.4449
# Epoch 59/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4450 - mae: 8.4450
# Epoch 60/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4338 - mae: 8.4338
# Epoch 61/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4225 - mae: 8.4225
# Epoch 62/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4113 - mae: 8.4113
# Epoch 63/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4174 - mae: 8.4174
# Epoch 64/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4113 - mae: 8.4113
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4000 - mae: 8.4000
# Epoch 66/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3888 - mae: 8.3888
# Epoch 67/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3786 - mae: 8.3786
# Epoch 68/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3888 - mae: 8.3888
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3775 - mae: 8.3775
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3663 - mae: 8.3663
# Epoch 71/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3550 - mae: 8.3550
# Epoch 72/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3511 - mae: 8.3511
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3550 - mae: 8.3550
# Epoch 74/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3438 - mae: 8.3438
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.3325 - mae: 8.3325
# Epoch 76/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3213 - mae: 8.3213
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3236 - mae: 8.3236
# Epoch 78/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3213 - mae: 8.3213
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 8.3100 - mae: 8.3100
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2988 - mae: 8.2988
# Epoch 81/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2875 - mae: 8.2875
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2961 - mae: 8.2961
# Epoch 83/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2875 - mae: 8.2875
# Epoch 84/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2763 - mae: 8.2763
# Epoch 85/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2650 - mae: 8.2650
# Epoch 86/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2574 - mae: 8.2574
# Epoch 87/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2650 - mae: 8.2650
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2538 - mae: 8.2538
# Epoch 89/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2425 - mae: 8.2425
# Epoch 90/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2313 - mae: 8.2313
# Epoch 91/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2299 - mae: 8.2299
# Epoch 92/100
# 1/1 [==============================] - 0s 15ms/step - loss: 8.2313 - mae: 8.2313
# Epoch 93/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.2200 - mae: 8.2200
# Epoch 94/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.2088 - mae: 8.2088
# Epoch 95/100
# 1/1 [==============================] - 0s 16ms/step - loss: 8.1975 - mae: 8.1975
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.2024 - mae: 8.2024
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.1975 - mae: 8.1975
# Epoch 98/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.1863 - mae: 8.1863
# Epoch 99/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.1750 - mae: 8.1750
# Epoch 100/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.1638 - mae: 8.1638

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[29.220901]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(100, activation="relu"),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 338ms/step - loss: 12.4199 - mae: 12.4199
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.9628 - mae: 11.9628
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.5002 - mae: 11.5002
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.0281 - mae: 11.0281
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.5473 - mae: 10.5473
# Epoch 6/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.0488 - mae: 10.0488
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5275 - mae: 9.5275
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9792 - mae: 8.9792
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4162 - mae: 8.4162
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.8876 - mae: 7.8876
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 7.3316 - mae: 7.3316
# Epoch 12/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.7391 - mae: 6.7391
# Epoch 13/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1029 - mae: 6.1029
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4154 - mae: 5.4154
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.6736 - mae: 4.6736
# Epoch 16/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4249 - mae: 4.4249
# Epoch 17/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3627 - mae: 4.3627
# Epoch 18/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3635 - mae: 4.3635
# Epoch 19/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3663 - mae: 4.3663
# Epoch 20/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3439 - mae: 4.3439
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3699 - mae: 4.3699
# Epoch 22/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3245 - mae: 4.3245
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3734 - mae: 4.3734
# Epoch 24/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3104 - mae: 4.3104
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3723 - mae: 4.3723
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3139 - mae: 4.3139
# Epoch 27/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3528 - mae: 4.3528
# Epoch 28/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3174 - mae: 4.3174
# Epoch 29/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3335 - mae: 4.3335
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3207 - mae: 4.3207
# Epoch 31/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.3143 - mae: 4.3143
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3239 - mae: 4.3239
# Epoch 33/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2953 - mae: 4.2953
# Epoch 34/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3271 - mae: 4.3271
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2765 - mae: 4.2765
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3339 - mae: 4.3339
# Epoch 37/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2705 - mae: 4.2705
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3288 - mae: 4.3288
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2735 - mae: 4.2735
# Epoch 40/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.3098 - mae: 4.3098
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2765 - mae: 4.2765
# Epoch 42/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2911 - mae: 4.2911
# Epoch 43/100
# 1/1 [==============================] - 0s 18ms/step - loss: 4.2794 - mae: 4.2794
# Epoch 44/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2725 - mae: 4.2725
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2823 - mae: 4.2823
# Epoch 46/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2540 - mae: 4.2540
# Epoch 47/100
# 1/1 [==============================] - 0s 15ms/step - loss: 4.2850 - mae: 4.2850
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2357 - mae: 4.2357
# Epoch 49/100
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2877 - mae: 4.2877
# Epoch 50/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2241 - mae: 4.2241
# Epoch 51/100
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2845 - mae: 4.2845
# Epoch 52/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2269 - mae: 4.2269
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2661 - mae: 4.2661
# Epoch 54/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2296 - mae: 4.2296
# Epoch 55/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2479 - mae: 4.2479
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2321 - mae: 4.2321
# Epoch 57/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2298 - mae: 4.2298
# Epoch 58/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2383 - mae: 4.2383
# Epoch 59/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2160 - mae: 4.2160
# Epoch 60/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2405 - mae: 4.2405
# Epoch 61/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1981 - mae: 4.1981
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2427 - mae: 4.2427
# Epoch 63/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1803 - mae: 4.1803
# Epoch 64/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2449 - mae: 4.2449
# Epoch 65/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1810 - mae: 4.1810
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2295 - mae: 4.2295
# Epoch 67/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1833 - mae: 4.1833
# Epoch 68/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2118 - mae: 4.2118
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1855 - mae: 4.1855
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1942 - mae: 4.1942
# Epoch 71/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1876 - mae: 4.1876
# Epoch 72/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1767 - mae: 4.1767
# Epoch 73/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1897 - mae: 4.1897
# Epoch 74/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1593 - mae: 4.1593
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1916 - mae: 4.1916
# Epoch 76/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1421 - mae: 4.1421
# Epoch 77/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1935 - mae: 4.1935
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1291 - mae: 4.1291
# Epoch 79/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1919 - mae: 4.1919
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1343 - mae: 4.1343
# Epoch 81/100
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1787 - mae: 4.1787
# Epoch 82/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1362 - mae: 4.1362
# Epoch 83/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1614 - mae: 4.1614
# Epoch 84/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1378 - mae: 4.1378
# Epoch 85/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1444 - mae: 4.1444
# Epoch 86/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1394 - mae: 4.1394
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1275 - mae: 4.1275
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1410 - mae: 4.1410
# Epoch 89/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1107 - mae: 4.1107
# Epoch 90/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1424 - mae: 4.1424
# Epoch 91/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.0941 - mae: 4.0941
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1438 - mae: 4.1438
# Epoch 93/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.0789 - mae: 4.0789
# Epoch 94/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1444 - mae: 4.1444
# Epoch 95/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0803 - mae: 4.0803
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1276 - mae: 4.1276
# Epoch 97/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0816 - mae: 4.0816
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1110 - mae: 4.1110
# Epoch 99/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0828 - mae: 4.0828
# Epoch 100/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0945 - mae: 4.0945

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-8., -5., -2.,  1.,  4.,  7., 10., 13.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[32.468384]], dtype=float32)

# %% [markdown]
# --> overfitting

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(50),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 282ms/step - loss: 13.2729 - mae: 13.2729
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 13.0132 - mae: 13.0132
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.7525 - mae: 12.7525
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.4901 - mae: 12.4901
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.2252 - mae: 12.2252
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9570 - mae: 11.9570
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.6850 - mae: 11.6850
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.4082 - mae: 11.4082
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.1259 - mae: 11.1259
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 10.8374 - mae: 10.8374
# Epoch 11/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.5418 - mae: 10.5418
# Epoch 12/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.2384 - mae: 10.2384
# Epoch 13/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9262 - mae: 9.9262
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.6045 - mae: 9.6045
# Epoch 15/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2723 - mae: 9.2723
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.9287 - mae: 8.9287
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.5728 - mae: 8.5728
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.4694 - mae: 8.4694
# Epoch 19/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4206 - mae: 8.4206
# Epoch 20/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3724 - mae: 8.3724
# Epoch 21/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4013 - mae: 8.4013
# Epoch 22/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3893 - mae: 8.3893
# Epoch 23/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3406 - mae: 8.3406
# Epoch 24/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2924 - mae: 8.2924
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2446 - mae: 8.2446
# Epoch 26/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2864 - mae: 8.2864
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2608 - mae: 8.2608
# Epoch 28/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2125 - mae: 8.2125
# Epoch 29/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.1646 - mae: 8.1646
# Epoch 30/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.1171 - mae: 8.1171
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.1623 - mae: 8.1623
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.1324 - mae: 8.1324
# Epoch 33/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0843 - mae: 8.0843
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0366 - mae: 8.0366
# Epoch 35/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.9892 - mae: 7.9892
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0285 - mae: 8.0285
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0035 - mae: 8.0035
# Epoch 38/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9554 - mae: 7.9554
# Epoch 39/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.9077 - mae: 7.9077
# Epoch 40/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.8603 - mae: 7.8603
# Epoch 41/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.8845 - mae: 7.8845
# Epoch 42/100
# 1/1 [==============================] - 0s 24ms/step - loss: 7.8734 - mae: 7.8734
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.8252 - mae: 7.8252
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7773 - mae: 7.7773
# Epoch 45/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7297 - mae: 7.7297
# Epoch 46/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7297 - mae: 7.7297
# Epoch 47/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7415 - mae: 7.7415
# Epoch 48/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6930 - mae: 7.6930
# Epoch 49/100
# 1/1 [==============================] - 0s 17ms/step - loss: 7.6447 - mae: 7.6447
# Epoch 50/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.5966 - mae: 7.5966
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5636 - mae: 7.5636
# Epoch 52/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.6070 - mae: 7.6070
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5580 - mae: 7.5580
# Epoch 54/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5092 - mae: 7.5092
# Epoch 55/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4605 - mae: 7.4605
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.4120 - mae: 7.4120
# Epoch 57/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4421 - mae: 7.4421
# Epoch 58/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4202 - mae: 7.4202
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.3706 - mae: 7.3706
# Epoch 60/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.3211 - mae: 7.3211
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2717 - mae: 7.2717
# Epoch 62/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2501 - mae: 7.2501
# Epoch 63/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2782 - mae: 7.2782
# Epoch 64/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2276 - mae: 7.2276
# Epoch 65/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1771 - mae: 7.1771
# Epoch 66/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.1267 - mae: 7.1267
# Epoch 67/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.0762 - mae: 7.0762
# Epoch 68/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0992 - mae: 7.0992
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0802 - mae: 7.0802
# Epoch 70/100
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0284 - mae: 7.0284
# Epoch 71/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9767 - mae: 6.9767
# Epoch 72/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9249 - mae: 6.9249
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.8784 - mae: 6.8784
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9268 - mae: 6.9268
# Epoch 75/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8735 - mae: 6.8735
# Epoch 76/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8202 - mae: 6.8202
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7669 - mae: 6.7669
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7134 - mae: 6.7134
# Epoch 79/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6952 - mae: 6.6952
# Epoch 80/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7123 - mae: 6.7123
# Epoch 81/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.6572 - mae: 6.6572
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6020 - mae: 6.6020
# Epoch 83/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.5466 - mae: 6.5466
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4911 - mae: 6.4911
# Epoch 85/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4936 - mae: 6.4936
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.4867 - mae: 6.4867
# Epoch 87/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4294 - mae: 6.4294
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3718 - mae: 6.3718
# Epoch 89/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3140 - mae: 6.3140
# Epoch 90/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2560 - mae: 6.2560
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2729 - mae: 6.2729
# Epoch 92/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.2481 - mae: 6.2481
# Epoch 93/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1881 - mae: 6.1881
# Epoch 94/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1278 - mae: 6.1278
# Epoch 95/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0671 - mae: 6.0671
# Epoch 96/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.0061 - mae: 6.0061
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.0322 - mae: 6.0322
# Epoch 98/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9944 - mae: 5.9944
# Epoch 99/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9312 - mae: 5.9312
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8677 - mae: 5.8677

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# array([[29.296755]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# create a model using Sequential API
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(50),
                             tf.keras.layers.Dense(1)
                             ])


# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
              metrics=["mae"])

# fit the model
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 354ms/step - loss: 13.2729 - mae: 13.2729
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.7634 - mae: 12.7634
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.2506 - mae: 12.2506
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.7329 - mae: 11.7329
# Epoch 5/100
# 1/1 [==============================] - 0s 10ms/step - loss: 11.2082 - mae: 11.2082
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.6741 - mae: 10.6741
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.1280 - mae: 10.1280
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.5675 - mae: 9.5675
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9901 - mae: 8.9901
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3938 - mae: 8.3938
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0758 - mae: 8.0758
# Epoch 12/100
# 1/1 [==============================] - 0s 24ms/step - loss: 8.2174 - mae: 8.2174
# Epoch 13/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4721 - mae: 8.4721
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.5513 - mae: 8.5513
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.4950 - mae: 8.4950
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3340 - mae: 8.3340
# Epoch 17/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0925 - mae: 8.0925
# Epoch 18/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.7893 - mae: 7.7893
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4787 - mae: 7.4787
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3509 - mae: 7.3509
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2251 - mae: 7.2251
# Epoch 22/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2327 - mae: 7.2327
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2520 - mae: 7.2520
# Epoch 24/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1907 - mae: 7.1907
# Epoch 25/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.0583 - mae: 7.0583
# Epoch 26/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8617 - mae: 6.8617
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.6146 - mae: 6.6146
# Epoch 28/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5213 - mae: 6.5213
# Epoch 29/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4209 - mae: 6.4209
# Epoch 30/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3134 - mae: 6.3134
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.1987 - mae: 6.1987
# Epoch 32/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0766 - mae: 6.0766
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9989 - mae: 5.9989
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.8372 - mae: 5.8372
# Epoch 35/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6498 - mae: 5.6498
# Epoch 36/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4891 - mae: 5.4891
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3220 - mae: 5.3220
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.1479 - mae: 5.1479
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0033 - mae: 5.0033
# Epoch 40/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8423 - mae: 4.8423
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6152 - mae: 4.6152
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4306 - mae: 4.4306
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2351 - mae: 4.2351
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0283 - mae: 4.0283
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8097 - mae: 3.8097
# Epoch 46/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.5791 - mae: 3.5791
# Epoch 47/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3359 - mae: 3.3359
# Epoch 48/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0795 - mae: 3.0795
# Epoch 49/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8096 - mae: 2.8096
# Epoch 50/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5352 - mae: 2.5352
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2492 - mae: 2.2492
# Epoch 52/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9567 - mae: 1.9567
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6477 - mae: 1.6477
# Epoch 54/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3216 - mae: 1.3216
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9780 - mae: 0.9780
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6162 - mae: 0.6162
# Epoch 57/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3070 - mae: 0.3070
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1556 - mae: 0.1556
# Epoch 59/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4589 - mae: 0.4589
# Epoch 60/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6769 - mae: 0.6769
# Epoch 61/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7978 - mae: 0.7978
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8939 - mae: 0.8939
# Epoch 63/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9364 - mae: 0.9364
# Epoch 64/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8755 - mae: 0.8755
# Epoch 65/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8073 - mae: 0.8073
# Epoch 66/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6965 - mae: 0.6965
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5573 - mae: 0.5573
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4783 - mae: 0.4783
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1951 - mae: 0.1951
# Epoch 70/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2230 - mae: 0.2230
# Epoch 71/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2408 - mae: 0.2408
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3801 - mae: 0.3801
# Epoch 73/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3557 - mae: 0.3557
# Epoch 74/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4093 - mae: 0.4093
# Epoch 75/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3511 - mae: 0.3511
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3301 - mae: 0.3301
# Epoch 77/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2076 - mae: 0.2076
# Epoch 78/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1165 - mae: 0.1165
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0901 - mae: 0.0901
# Epoch 80/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1657 - mae: 0.1657
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2278 - mae: 0.2278
# Epoch 82/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2082 - mae: 0.2082
# Epoch 83/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1881 - mae: 0.1881
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1219 - mae: 0.1219
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1675 - mae: 0.1675
# Epoch 86/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1103 - mae: 0.1103
# Epoch 87/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1391 - mae: 0.1391
# Epoch 88/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1786 - mae: 0.1786
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0977 - mae: 0.0977
# Epoch 90/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0618 - mae: 0.0618
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3359 - mae: 0.3359
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3127 - mae: 0.3127
# Epoch 93/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1665 - mae: 0.1665
# Epoch 94/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3087 - mae: 0.3087
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1475 - mae: 0.1475
# Epoch 96/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2866 - mae: 0.2866
# Epoch 97/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2412 - mae: 0.2412
# Epoch 98/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1195 - mae: 0.1195
# Epoch 99/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1131 - mae: 0.1131
# Epoch 100/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2041 - mae: 0.2041

# %%
# try and a prediction using the model to see if improvement
model.predict([16.0])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f144bdcf050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[27.288563]], dtype=float32)

# %% [markdown]
# --> not perfect but better
#
# --> changing learning rate often efficient as well as fitting with more data

# %% [markdown]
# ### evaluating model
#
# In practice, typical workflow =
# Build a model --> fit it --> evaluate it --> tweak it  --> fit it --> evaluate it --> tweak it ....
# When it comes to evaluation, there are 3 words to remember: "visualize, visualize, visualize."
#
# It's a good idea to visualize:
#
# *   The data - what data are you working with? What does it look like?
# *   The model itself - what does the architecture look like? What are the different shapes?
# *   The training of a model - how does a model perform while it learns?
# *   The predictions of a model - how do the predictions of a model line up against the ground truth (the original labels)?

# %%
# Make a bigger dataset
X = np.arange(-100, 100, 4)
X
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
# Make labels for the dataset (adhering to the same pattern as before)
y = np.arange(-90, 110, 4)
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Same result as above
y = X + 10
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# ### The 3 sets
# One of the other most common and important steps in a machine learning project is creating a training and test set (and when required, a validation set).
#
# Here are the 3 sets:
#
# * **Training set** - the model learns from this data, which is typically 70-80% of the total data available (like the course materials you study during the semester).
# * **Validation set** - the model gets tuned on this data, which is typically 10-15% of the total data available (like the practice exam you take before the final exam).
# * **Test set** - the model gets evaluated on this data to test what it has learned, it's typically 10-15% of the total data available (like the final exam you take at the end of the semester).
